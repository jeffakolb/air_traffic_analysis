# %%
import csv
import pandas as pd

# %%
#df = pd.read_csv("data/air_segment_data_2017_12_with_craft_type.csv",
df = pd.read_csv("data/air_segment_data_2017_12.csv",
                 sep=',',                 
                 quotechar='"',
                 header=0,
                )

# %%
df.head()
# Out:
#    DEPARTURES_SCHEDULED  PASSENGERS CARRIER           CARRIER_NAME ORIGIN  \
# 0                   0.0       172.0      WG  Sunwing Airlines Inc.    MCO
# 1                   0.0       150.0      WG  Sunwing Airlines Inc.    MCO
# 2                   0.0        93.0      WG  Sunwing Airlines Inc.    PIE
# 3                   0.0         2.0     0CQ   ACM AIR CHARTER GmbH    EWR
# 4                   0.0         2.0     0CQ   ACM AIR CHARTER GmbH    HNL
#
#      ORIGIN_CITY_NAME DEST       DEST_CITY_NAME  AIRCRAFT_TYPE  YEAR  MONTH  \
# 0         Orlando, FL  FLL  Fort Lauderdale, FL            614  2017     12
# 1         Orlando, FL  PIE   St. Petersburg, FL            614  2017     12
# 2  St. Petersburg, FL  MCO          Orlando, FL            614  2017     12
# 3          Newark, NJ  OPF            Miami, FL            614  2017     12
# 4        Honolulu, HI  LAX      Los Angeles, CA            682  2017     12
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
# ...

# %%
aircraft_df = pd.read_csv('data/aircraft_type.csv')

# %%
aircraft_df.head()
# Out:
#    Code                                Description
# 0     7                         Aero Commander 200
# 1     8                          Aero Macchi AL-60
# 2     9                               Aeronca 7-AC
# 3    10  Beech Bonanza 35A/C/D/E/G/H/J/K/S/V/  36A
# 4    20                            Bellanca CH-300

# %%
pd.merge(df,aircraft_df,left_on="AIRCRAFT_TYPE",right_on="Code")
# Out:
#        DEPARTURES_SCHEDULED  PASSENGERS CARRIER                 CARRIER_NAME  \
# 0                       0.0       172.0      WG        Sunwing Airlines Inc.
# 1                       0.0       150.0      WG        Sunwing Airlines Inc.
# 2                       0.0        93.0      WG        Sunwing Airlines Inc.
# 3                       0.0         2.0     0CQ         ACM AIR CHARTER GmbH
# 4                       0.0         4.0     0CQ         ACM AIR CHARTER GmbH
# 5                       0.0         9.0     0CQ         ACM AIR CHARTER GmbH
# 6                       0.0         2.0     0CQ         ACM AIR CHARTER GmbH
# 7                       0.0        12.0     0CQ         ACM AIR CHARTER GmbH
# 8                       0.0         1.0     0CQ         ACM AIR CHARTER GmbH
# 9                       0.0       133.0      DL         Delta Air Lines Inc.
# 10                      0.0       120.0      DL         Delta Air Lines Inc.
# ...
